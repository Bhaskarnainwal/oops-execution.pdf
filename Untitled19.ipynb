# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhaskarnainwal/oops-execution.pdf/blob/main/Untitled19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
empty_list = []
empty_list


[]


another_empty_list = list()
another_empty_list


[]


another_empty_list.append(2)
another_empty_list


[2]


another_empty_list.append(1)
another_empty_list.append(3)
another_empty_list


[2, 1, 3, 1, 3]


another_empty_list.index(3)


2


the_sixth_sense = 6
print(type(the_sixth_sense))


<class 'int'>


two_and_a_half_men = 2.5
print(type(two_and_a_half_men))


<class 'float'>


another_list = list()
tharoor = {'farrago': 'a confused mixture'}
print(type(tharoor))


<class 'dict'>


schindlers_list = list()
print(type(schindlers_list))


<class 'list'>


another_list = list()
tharoor = {'farrago': 'a confused mixture'}
print(type(tharoor))


<class 'dict'>


#Create a new object type called FirstClass
class FirstClass:
  pass


#Instance of FirstClass
x = FirstClass()
print(type(x))


<class '_main_.FirstClass'>


y = FirstClass()
print(type(y))


<class '_main_.FirstClass'>


#Attributes
class Dog:
  def _init_(self, breed, name):
    self.breed_attribute = breed
    self.name_attribute = name


sam_object = Dog(breed='Lab', name='Sam')
frank_object = Dog(breed='Huskie', name='Frank')


sam_object.breed_attribute


'Lab'


frank_object.name_attribute


'Frank'


#Circle class
class Circle:
  def _init_(self, radius = 1):
    self.radius = radius
    self.area = 3.14 * radius * radius

  def setRadius(self, new_radius):
      self.radius = new_radius
      self.area = 3.14 * new_radius * new_radius

  def getCircumference(self):
      return 2 * 3.14 * self.radius

c = Circle(2)
c.area


12.56


c.setRadius(10)
print(c.getCircumference())


62.800000000000004


print('Radius is: ', c.radius)
print('Area is: ', c.area)
print('Circumference is: ', c.getCircumference())


Radius is:  10
Area is:  314.0
Circumference is:  62.800000000000004


#Changing the radius
c.setRadius(4)
print('radius is: ', c.radius)
print('Area is: ', c.area)
print('Circumference is: ', c.getCircumference())


radius is:  4
Area is:  50.24
Circumference is:  25.12


#Polymorphism
class HouseStark:
  def _init_(self, sigil):
    self.sigil = sigil

  def motto(self):
    return "house stark with sigil " + self.sigil + "has the motto 'Winter is Coming'"

class HouseTargaryen:
  def _init_(self, sigil):
    self.sigil = sigil

  def motto(self):
      return "house targaryen with sigil " + self.sigil + "has the motto 'Fire and Blood'"


arya = HouseStark('direwolf')
danaerys = HouseTargaryen('dragon')

print(arya.motto())


house stark with sigil direwolfhas the motto 'Winter is Coming'


print(danaerys.motto())


house targaryen with sigil dragonhas the motto 'Fire and Blood'


for warrior in [arya, danaerys]:
  print(warrior.motto())


house stark with sigil direwolfhas the motto 'Winter is Coming'
house targaryen with sigil dragonhas the motto 'Fire and Blood'


def get_motto(warrior):
  print(warrior.motto())

get_motto(arya)
get_motto(danaerys)


house stark with sigil direwolfhas the motto 'Winter is Coming'
house targaryen with sigil dragonhas the motto 'Fire and Blood'


#Try and except
try:
  print("good to go")
  print('sss')
  print('top','class')
except:
  print('yesss')
  print('hahaha')
  print('blabla')
else:
  print("t r u e")
  print(' no matter')
  print('what')


good to go
sss
top class
t r u e
 no matter
what


#Finally
try:
  print("execute try statements")
except:
  print("neverrrr")
finally:
  print("finally always")


execute try statements
finally always


#A real world case example
'''
uber price calculation
'''
def get_price_per_km(hour):

  if (hour>8 & (hour<11)):
    price_per_km = 20
  elif (hour>18 & (hour<21)):
    price_per_km = 25
  else:
    price_per_km = 30
  return price_per_km



'''
production grade code
'''
class SurgePricing:
    def _init_(self):
        pass
    def get_price_per_km(self, hour):
        try:
            if (hour > 8 and (hour < 11)):
                price_per_km = 20
            elif (hour > 18 and (hour < 21)):
                price_per_km = 25
            else:
                price_per_km = 30
        except:
            price_per_km = 10
        return price_per_km
# Out:
#   File "<ipython-input-3-031fca3529a3>", line 40
#     <class 'int'>
#     ^
# SyntaxError: invalid syntax
